# %%
#Loading the required libraries
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
fifa=pd.read_csv('fifa_players_22.csv')
# Out:
# C:\Users\ravin\AppData\Local\Temp\ipykernel_11632\63629067.py:1: DtypeWarning: Columns (25,108) have mixed types. Specify dtype option on import or set low_memory=False.
#   fifa=pd.read_csv('fifa_players_22.csv')

# %%
fifa.head()
# Out:
#    sofifa_id                                         player_url  \
# 0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1     188545  https://sofifa.com/player/188545/robert-lewand...
# 2      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 3     190871  https://sofifa.com/player/190871/neymar-da-sil...
# 4     192985  https://sofifa.com/player/192985/kevin-de-bruy...
#
#           short_name                            long_name player_positions  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini       RW, ST, CF
# 1     R. Lewandowski                   Robert Lewandowski               ST
# 2  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro           ST, LW
# 3          Neymar Jr        Neymar da Silva Santos Júnior          LW, CAM
# 4       K. De Bruyne                      Kevin De Bruyne          CM, CAM
#
#    overall  potential    value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
fifa.shape
# Out:
# (19239, 110)

# %%
for col in fifa.columns:
    print(col)
# Out:
# sofifa_id
# player_url
# short_name
# long_name
# player_positions
# overall
# potential
# value_eur
# wage_eur
# age
# dob
# height_cm
# weight_kg
# club_team_id
# club_name
# league_name
# league_level
# club_position
# club_jersey_number
# club_loaned_from
# club_joined
# club_contract_valid_until
# nationality_id
# nationality_name
# nation_team_id
# nation_position
# nation_jersey_number
# preferred_foot
# weak_foot
# skill_moves
# international_reputation
# work_rate
# body_type
# real_face
# release_clause_eur
# player_tags
# player_traits
# pace
# shooting
# passing
# dribbling
# defending
# physic
# attacking_crossing
# attacking_finishing
# attacking_heading_accuracy
# attacking_short_passing
# attacking_volleys
# skill_dribbling
# skill_curve
# skill_fk_accuracy
# skill_long_passing
# skill_ball_control
# movement_acceleration
# movement_sprint_speed
# movement_agility
# movement_reactions
# movement_balance
# power_shot_power
# power_jumping
# power_stamina
# ...

# %%
fifa['nationality_name'].value_counts()
# Out:
# nationality_name
# England             1719
# Germany             1214
# Spain               1086
# France               980
# Argentina            960
#                     ...
# Ethiopia               1
# Papua New Guinea       1
# Kyrgyzstan             1
# Guam                   1
# Indonesia              1
# Name: count, Length: 163, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:10]
# Out:
# nationality_name
# England          1719
# Germany          1214
# Spain            1086
# France            980
# Argentina         960
# Brazil            897
# Japan             546
# Netherlands       439
# United States     413
# Poland            403
# Name: count, dtype: int64

# %%
fifa['nationality_name'].value_counts()[0:10].keys()
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Japan',
#        'Netherlands', 'United States', 'Poland'],
#       dtype='object', name='nationality_name')

# %%
plt.figure(figsize=(15,5))
plt.bar(list(fifa['nationality_name'].value_counts()[0:10].keys()),list(fifa['nationality_name'].value_counts()[0:10]),color='green')
plt.show()

# %%
player_salary=fifa[['short_name','wage_eur']]

# %%
player_salary.head()
# Out:
#           short_name  wage_eur
# 0           L. Messi  320000.0
# 1     R. Lewandowski  270000.0
# 2  Cristiano Ronaldo  270000.0
# 3          Neymar Jr  270000.0
# 4       K. De Bruyne  350000.0

# %%
player_salary_desc=player_salary.sort_values(by=['wage_eur'],ascending=False)

# %%
player_salary_desc.head()
# Out:
#       short_name  wage_eur
# 4   K. De Bruyne  350000.0
# 11    K. Benzema  350000.0
# 0       L. Messi  320000.0
# 24      T. Kroos  310000.0
# 14      Casemiro  310000.0

# %%
plt.figure(figsize=(7,4))
plt.bar(list(player_salary_desc['short_name'])[0:5],list(player_salary_desc['wage_eur'])[0:5],color=['red','green','blue','pink','orange'])
plt.show()

# %%
#condition for germany
fifa['nationality_name']=='germany'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19234    False
# 19235    False
# 19236    False
# 19237    False
# 19238    False
# Name: nationality_name, Length: 19239, dtype: bool

# %%
germany=fifa[fifa['nationality_name']=='Germany']

# %%
germany.head(10)
# Out:
#     sofifa_id                                         player_url  \
# 7      167495  https://sofifa.com/player/167495/manuel-neuer/...
# 8      192448  https://sofifa.com/player/192448/marc-andre-te...
# 19     212622  https://sofifa.com/player/212622/joshua-kimmic...
# 24     182521  https://sofifa.com/player/182521/toni-kroos/22...
# 35     189596  https://sofifa.com/player/189596/thomas-muller...
# 40     209658  https://sofifa.com/player/209658/leon-goretzka...
# 49     178603  https://sofifa.com/player/178603/mats-hummels/...
# 78     186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 79     188350  https://sofifa.com/player/188350/marco-reus/22...
# 89     206113  https://sofifa.com/player/206113/serge-gnabry/...
#
#        short_name                long_name player_positions  overall  \
# 7        M. Neuer       Manuel Peter Neuer               GK       90
# 8   M. ter Stegen    Marc-André ter Stegen               GK       90
# ...

# %%
germany.sort_values(by=['height_cm'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 15084     262899  https://sofifa.com/player/262899/cottrell-ezek...
# 16695     253410  https://sofifa.com/player/253410/jonas-hupe/22...
# 10463     236831  https://sofifa.com/player/236831/aaron-seydel/...
# 2064      199833  https://sofifa.com/player/199833/lars-unnersta...
# 18284     259089  https://sofifa.com/player/259089/marc-richter/...
#
#           short_name                 long_name player_positions  overall  \
# 15084     C. Ezekwem          Cottrell Ezekwem               CB       61
# 16695        J. Hupe                Jonas Hupe               GK       58
# 10463      A. Seydel              Aaron Seydel      ST, LM, CAM       65
# 2064   L. Unnerstall           Lars Unnerstall               GK       74
# 18284     M. Richter  Marc Paul Victor Richter               GK       54
#
#        potential  value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
germany.sort_values(by=['weight_kg'],ascending=False).head()
# Out:
#        sofifa_id                                         player_url  \
# 13773     239746  https://sofifa.com/player/239746/lukas-watkowi...
# 2064      199833  https://sofifa.com/player/199833/lars-unnersta...
# 3846      158777  https://sofifa.com/player/158777/philipp-tscha...
# 244       212190  https://sofifa.com/player/212190/niklas-sule/2...
# 759       213331  https://sofifa.com/player/213331/jonathan-tah/...
#
#           short_name          long_name player_positions  overall  potential  \
# 13773   L. Watkowiak    Lukas Watkowiak               GK       62         67
# 2064   L. Unnerstall    Lars Unnerstall               GK       74         74
# 3846    P. Tschauner  Philipp Tschauner               GK       71         71
# 244          N. Süle        Niklas Süle           CB, RB       82         87
# 759           J. Tah       Jonathan Tah               CB       78         82
#
#         value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
germany.sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 24      182521  https://sofifa.com/player/182521/toni-kroos/22...
# 8       192448  https://sofifa.com/player/192448/marc-andre-te...
# 78      186942  https://sofifa.com/player/186942/ilkay-gundoga...
# 19      212622  https://sofifa.com/player/212622/joshua-kimmic...
# 126     212188  https://sofifa.com/player/212188/timo-werner/2...
#
#         short_name              long_name player_positions  overall  \
# 24        T. Kroos             Toni Kroos               CM       88
# 8    M. ter Stegen  Marc-André ter Stegen               GK       90
# 78     İ. Gündoğan         İlkay Gündoğan          CM, CDM       85
# 19      J. Kimmich  Joshua Walter Kimmich          CDM, RB       89
# 126      T. Werner            Timo Werner           ST, LW       84
#
#      potential    value_eur  wage_eur  age  ...   lcb    cb   rcb    rb    gk  \
# ...

# %%
germany[['short_name','wage_eur']].sort_values(by=['wage_eur'],ascending=False).head()
# Out:
#         short_name  wage_eur
# 24        T. Kroos  310000.0
# 8    M. ter Stegen  250000.0
# 78     İ. Gündoğan  185000.0
# 19      J. Kimmich  160000.0
# 126      T. Werner  155000.0

# %%
#shooting
player_shooting=fifa[['short_name','shooting']]
player_shooting.head(10)
# Out:
#           short_name  shooting
# 0           L. Messi      92.0
# 1     R. Lewandowski      92.0
# 2  Cristiano Ronaldo      94.0
# 3          Neymar Jr      83.0
# 4       K. De Bruyne      86.0
# 5           J. Oblak       NaN
# 6          K. Mbappé      88.0
# 7           M. Neuer       NaN
# 8      M. ter Stegen       NaN
# 9            H. Kane      91.0

# %%
player_shooting.sort_values(by=['shooting'],ascending=False).head(10)
# Out:
#            short_name  shooting
# 2   Cristiano Ronaldo      94.0
# 0            L. Messi      92.0
# 1      R. Lewandowski      92.0
# 29         E. Haaland      91.0
# 9             H. Kane      91.0
# 23          L. Suárez      90.0
# 30          S. Agüero      89.0
# 6           K. Mbappé      88.0
# 13             H. Son      87.0
# 25          R. Lukaku      87.0

# %%
#defending
player_defending=fifa[['short_name','defending','nationality_name','club_name']]

# %%
player_defending.head(10)
# Out:
#           short_name  defending nationality_name            club_name
# 0           L. Messi       34.0        Argentina  Paris Saint-Germain
# 1     R. Lewandowski       44.0           Poland    FC Bayern München
# 2  Cristiano Ronaldo       34.0         Portugal    Manchester United
# 3          Neymar Jr       37.0           Brazil  Paris Saint-Germain
# 4       K. De Bruyne       64.0          Belgium      Manchester City
# 5           J. Oblak        NaN         Slovenia   Atlético de Madrid
# 6          K. Mbappé       36.0           France  Paris Saint-Germain
# 7           M. Neuer        NaN          Germany    FC Bayern München
# 8      M. ter Stegen        NaN          Germany         FC Barcelona
# 9            H. Kane       47.0          England    Tottenham Hotspur

# %%
player_defending.sort_values(by=['defending'],ascending=False).head(10)
# Out:
#       short_name  defending nationality_name            club_name
# 15   V. van Dijk       91.0      Netherlands            Liverpool
# 49    M. Hummels       89.0          Germany    Borussia Dortmund
# 47  G. Chiellini       89.0            Italy             Juventus
# 39    Marquinhos       89.0           Brazil  Paris Saint-Germain
# 46    Rúben Dias       88.0         Portugal      Manchester City
# 22  Sergio Ramos       88.0            Spain  Paris Saint-Germain
# 68   M. Škriniar       87.0         Slovakia                Inter
# 84    S. de Vrij       87.0      Netherlands                Inter
# 57     R. Varane       87.0           France    Manchester United
# 56  K. Koulibaly       87.0          Senegal               Napoli

# %%
real_madrid=fifa[fifa['club_name']=='Real Madrid CF']

# %%
real_madrid.head(10)
# Out:
#      sofifa_id                                         player_url  \
# 11      165153  https://sofifa.com/player/165153/karim-benzema...
# 12      192119  https://sofifa.com/player/192119/thibaut-court...
# 14      200145  https://sofifa.com/player/200145/carlos-henriq...
# 24      182521  https://sofifa.com/player/182521/toni-kroos/22...
# 32      177003  https://sofifa.com/player/177003/luka-modric/2...
# 75      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 87      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 107     197445  https://sofifa.com/player/197445/david-alaba/2...
# 182     220834  https://sofifa.com/player/220834/marco-asensio...
# 187     228618  https://sofifa.com/player/228618/ferland-mendy...
#
#         short_name                          long_name player_positions  \
# 11      K. Benzema                      Karim Benzema           CF, ST
# 12     T. Courtois                   Thibaut Courtois               GK
# ...

# %%
real_madrid.sort_values(by=['wage_eur'],ascending=False).head(10)
# Out:
#      sofifa_id                                         player_url  \
# 11      165153  https://sofifa.com/player/165153/karim-benzema...
# 14      200145  https://sofifa.com/player/200145/carlos-henriq...
# 24      182521  https://sofifa.com/player/182521/toni-kroos/22...
# 12      192119  https://sofifa.com/player/192119/thibaut-court...
# 75      183277  https://sofifa.com/player/183277/eden-hazard/2...
# 87      204963  https://sofifa.com/player/204963/daniel-carvaj...
# 107     197445  https://sofifa.com/player/197445/david-alaba/2...
# 32      177003  https://sofifa.com/player/177003/luka-modric/2...
# 182     220834  https://sofifa.com/player/220834/marco-asensio...
# 223     197781  https://sofifa.com/player/197781/francisco-rom...
#
#         short_name                          long_name player_positions  \
# 11      K. Benzema                      Karim Benzema           CF, ST
# 14        Casemiro  Carlos Henrique Venancio Casimiro              CDM
# ...

# %%
real_madrid.sort_values(by=['shooting'],ascending=False).head(10)
# Out:
#       sofifa_id                                         player_url  \
# 11       165153  https://sofifa.com/player/165153/karim-benzema...
# 204      173731  https://sofifa.com/player/173731/gareth-bale/2...
# 24       182521  https://sofifa.com/player/182521/toni-kroos/22...
# 75       183277  https://sofifa.com/player/183277/eden-hazard/2...
# 182      220834  https://sofifa.com/player/220834/marco-asensio...
# 631      232432  https://sofifa.com/player/232432/luka-jovic/22...
# 1751     221639  https://sofifa.com/player/221639/mariano-diaz-...
# 32       177003  https://sofifa.com/player/177003/luka-modric/2...
# 656      243812  https://sofifa.com/player/243812/rodrygo-silva...
# 223      197781  https://sofifa.com/player/197781/francisco-rom...
#
#          short_name                       long_name player_positions  overall  \
# 11       K. Benzema                   Karim Benzema           CF, ST       89
# ...

# %%
real_madrid.sort_values(by=['defending'],ascending=False).head()
# Out:
#      sofifa_id                                         player_url  \
# 14      200145  https://sofifa.com/player/200145/carlos-henriq...
# 107     197445  https://sofifa.com/player/197445/david-alaba/2...
# 279     240130  https://sofifa.com/player/240130/eder-gabriel-...
# 316     200724  https://sofifa.com/player/200724/jose-ignacio-...
# 87      204963  https://sofifa.com/player/204963/daniel-carvaj...
#
#           short_name                          long_name player_positions  \
# 14          Casemiro  Carlos Henrique Venancio Casimiro              CDM
# 107         D. Alaba             David Olatukunbo Alaba           CB, LB
# 279     Éder Militão               Éder Gabriel Militão               CB
# 316  Nacho Fernández    José Ignacio Fernández Iglesias       CB, RB, LB
# 87          Carvajal              Daniel Carvajal Ramos               RB
#
#      overall  potential   value_eur  wage_eur  age  ...   lcb    cb   rcb  \
# ...

# %%
real_madrid['nationality_name'].value_counts()
# Out:
# nationality_name
# Spain                 14
# Brazil                 5
# France                 3
# Belgium                2
# Germany                1
# Croatia                1
# Austria                1
# Uruguay                1
# Wales                  1
# Serbia                 1
# Dominican Republic     1
# Ukraine                1
# Japan                  1
# Name: count, dtype: int64

# %%
#fifa_india
fifa['nationality_name']=='India'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 19234    False
# 19235    False
# 19236    False
# 19237    False
# 19238     True
# Name: nationality_name, Length: 19239, dtype: bool

# %%
india_player=fifa[fifa['nationality_name']=='India']

# %%
india_player.head(10)
# Out:
#        sofifa_id                                         player_url  \
# 6509      190939  https://sofifa.com/player/190939/sunil-chhetri...
# 11417     225213  https://sofifa.com/player/225213/gurpreet-sing...
# 12312     193913  https://sofifa.com/player/193913/arindam-bhatt...
# 12515     223760  https://sofifa.com/player/223760/amrinder-sing...
# 12563     228188  https://sofifa.com/player/228188/pritam-kotal/...
# 13656     231933  https://sofifa.com/player/231933/rowllin-borge...
# 13892     245170  https://sofifa.com/player/245170/anirudh-thapa...
# 14546     231932  https://sofifa.com/player/231932/lallianzuala-...
# 14708     245165  https://sofifa.com/player/245165/subhasish-bos...
# 14770     248296  https://sofifa.com/player/248296/seriton-ferna...
#
#             short_name              long_name player_positions  overall  \
# 6509        S. Chhetri          Sunil Chhetri           ST, LM       68
# 11417  G. Singh Sandhu  Gurpreet Singh Sandhu               GK       64
# ...

# %%
india_player_defending=india_player[['short_name','defending','shooting','club_name']]
india_player_defending.head()
# Out:
#             short_name  defending  shooting           club_name
# 6509        S. Chhetri       32.0      71.0        Bengaluru FC
# 11417  G. Singh Sandhu        NaN       NaN        Bengaluru FC
# 12312  A. Bhattacharya        NaN       NaN   SC East Bengal FC
# 12515         A. Singh        NaN       NaN  ATK Mohun Bagan FC
# 12563         P. Kotal       60.0      39.0  ATK Mohun Bagan FC

# %%
india_player_defending.sort_values(by=['shooting'],ascending=False).head(10)
# Out:
#           short_name  defending  shooting            club_name
# 6509      S. Chhetri       32.0      71.0         Bengaluru FC
# 16653       M. Singh       31.0      58.0   ATK Mohun Bagan FC
# 16564     I. Pandita       23.0      57.0        Jamshedpur FC
# 16545       J. Singh       21.0      56.0    SC East Bengal FC
# 18430       B. Singh       19.0      56.0    SC East Bengal FC
# 17400       B. Singh       35.0      56.0         Bengaluru FC
# 17158      J. Justin       37.0      55.0        Chennaiyin FC
# 17520     S. Doungel       29.0      55.0        Jamshedpur FC
# 18534  W. Lalnunfela       18.0      55.0  NorthEast United FC
# 17268      VP Suhair       30.0      54.0  NorthEast United FC

# %%
india_player_defending.sort_values(by=['defending'],ascending=False).head(10)
# Out:
#          short_name  defending  shooting           club_name
# 13656     R. Borges       60.0      41.0      Mumbai City FC
# 12563      P. Kotal       60.0      39.0  ATK Mohun Bagan FC
# 15479      R. Bheke       58.0      35.0      Mumbai City FC
# 16532        N. Das       57.0      26.0       Chennaiyin FC
# 16553     P. Halder       57.0      45.0       Jamshedpur FC
# 14708       S. Bose       57.0      28.0  ATK Mohun Bagan FC
# 14770  S. Fernandes       56.0      32.0              FC Goa
# 16028      C. Singh       56.0      26.0        Hyderabad FC
# 16197         Apuia       56.0      47.0      Mumbai City FC
# 15480       A. Khan       56.0      48.0   SC East Bengal FC

# %%
india_player[['club_name']].value_counts()
# Out:
# club_name
# SC East Bengal FC      24
# Odisha FC              23
# Chennaiyin FC          22
# Hyderabad FC           22
# Bengaluru FC           21
# FC Goa                 21
# Kerala Blasters FC     20
# NorthEast United FC    19
# ATK Mohun Bagan FC     17
# Jamshedpur FC          17
# Mumbai City FC         17
# Name: count, dtype: int64
